# %%
# Import dependencies
import pandas as pd

# %%
# Import Spotify csv
zipped_spotify_data = pd.read_csv('Data/Spotify.zip')
old_spotify_df = pd.DataFrame(zipped_spotify_data)
old_spotify_df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# 1  ['2d0hyoQ5ynDBnkvAbJKORj']             2            1      True
# 2  ['2d0hyoQ5ynDBnkvAbJKORj']             3            1     False
# 3  ['2d0hyoQ5ynDBnkvAbJKORj']             4            1      True
# 4  ['2d0hyoQ5ynDBnkvAbJKORj']             5            1     False
#
#    danceability  ...  speechiness  acousticness  instrumentalness  liveness  \
# 0         0.470  ...       0.0727       0.02610          0.000011    0.3560
# 1         0.599  ...       0.1880       0.01290          0.000071    0.1550
# 2         0.315  ...       0.4830       0.02340          0.000002    0.1220
# 3         0.440  ...       0.2370       0.16300          0.000004    0.1210
# 4         0.426  ...       0.0701       0.00162          0.105000    0.0789
#
#    valence    tempo  duration_ms  time_signature  year  release_date
# 0    0.503  117.906       210133             4.0  1999    1999-11-02
# 1    0.489  103.680       206200             4.0  1999    1999-11-02
# 2    0.370  149.749       298893             4.0  1999    1999-11-02
# 3    0.574   96.752       213640             4.0  1999    1999-11-02
# 4    0.539  127.059       205600             4.0  1999    1999-11-02
#
# [5 rows x 24 columns]

# %%
# Import Spotify csv -- for individual file
# spotify_data = pd.read_csv('Data/tracks_features.csv')
# old_spotify_df = pd.DataFrame(spotify_data)
# old_spotify_df.head()

# %%
# Double check that all of the data was imported (all 1.2 million unique values)
len(old_spotify_df)
# Out:
# 1204025

# %%
# Remove [] from artists list
old_spotify_df['artists'] = old_spotify_df['artists'].astype(str)

# %%
# Clean up data from csv
# Valence is how positive a song sounds -- 1 = extremely positive, 0 = extremely negative

# %%
# Columns to drop: id, album_id, artist_ids, track_number, disk_number, speechiness, 
# acousticness, instrumentalness, liveness, time signature
# Columns to keep: 'name', 'album', 'artists', 'explicit', 'valence', 'tempo', 'duration_ms', 'year', 'release_date'
spotify_cols = ['name', 'album', 'artists', 'explicit', 'valence', 'tempo', 'duration_ms', 'year', 'release_date']
spotify_df = old_spotify_df[spotify_cols].copy()
spotify_df.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  explicit  valence    tempo  duration_ms  \
# 0  ['Rage Against The Machine']     False    0.503  117.906       210133
# 1  ['Rage Against The Machine']      True    0.489  103.680       206200
# 2  ['Rage Against The Machine']     False    0.370  149.749       298893
# 3  ['Rage Against The Machine']      True    0.574   96.752       213640
# 4  ['Rage Against The Machine']     False    0.539  127.059       205600
#
#    year release_date
# 0  1999   1999-11-02
# 1  1999   1999-11-02
# 2  1999   1999-11-02
# 3  1999   1999-11-02
# 4  1999   1999-11-02

# %%
# Convert duration_ms to duration_sec
spotify_df['duration_sec'] = spotify_df['duration_ms']/1000
spotify_df.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  explicit  valence    tempo  duration_ms  \
# 0  ['Rage Against The Machine']     False    0.503  117.906       210133
# 1  ['Rage Against The Machine']      True    0.489  103.680       206200
# 2  ['Rage Against The Machine']     False    0.370  149.749       298893
# 3  ['Rage Against The Machine']      True    0.574   96.752       213640
# 4  ['Rage Against The Machine']     False    0.539  127.059       205600
#
#    year release_date  duration_sec
# 0  1999   1999-11-02       210.133
# 1  1999   1999-11-02       206.200
# 2  1999   1999-11-02       298.893
# 3  1999   1999-11-02       213.640
# 4  1999   1999-11-02       205.600

# %%
# Convert duration_ms to duration_sec
spotify_df['duration_min'] = spotify_df['duration_sec']/60
spotify_df.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  explicit  valence    tempo  duration_ms  \
# 0  ['Rage Against The Machine']     False    0.503  117.906       210133
# 1  ['Rage Against The Machine']      True    0.489  103.680       206200
# 2  ['Rage Against The Machine']     False    0.370  149.749       298893
# 3  ['Rage Against The Machine']      True    0.574   96.752       213640
# 4  ['Rage Against The Machine']     False    0.539  127.059       205600
#
#    year release_date  duration_sec  duration_min
# 0  1999   1999-11-02       210.133      3.502217
# 1  1999   1999-11-02       206.200      3.436667
# 2  1999   1999-11-02       298.893      4.981550
# 3  1999   1999-11-02       213.640      3.560667
# 4  1999   1999-11-02       205.600      3.426667

# %%
# Drop duration_ms
spotify_df = spotify_df.drop(['duration_ms'], axis=1)

# %%
spotify_df.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  explicit  valence    tempo  year  \
# 0  ['Rage Against The Machine']     False    0.503  117.906  1999
# 1  ['Rage Against The Machine']      True    0.489  103.680  1999
# 2  ['Rage Against The Machine']     False    0.370  149.749  1999
# 3  ['Rage Against The Machine']      True    0.574   96.752  1999
# 4  ['Rage Against The Machine']     False    0.539  127.059  1999
#
#   release_date  duration_sec  duration_min
# 0   1999-11-02       210.133      3.502217
# 1   1999-11-02       206.200      3.436667
# 2   1999-11-02       298.893      4.981550
# 3   1999-11-02       213.640      3.560667
# 4   1999-11-02       205.600      3.426667

# %%
# Set name as index
# new_spotify = spotify_df.set_index('name')
# new_spotify.head()

# Get rid of extra brackets in artists
# spotify_df["artists_new"] = [x.replace("', '", "|").replace("'", "").replace("[", "").replace("]", "") for x in spotify_df["artists"]]
# spotify_df.head()

# %%
# Get rid of extra brackets and quotes in artists
spotify_df["new_artists"] = [x.replace("', '", ", ").replace("'", "").replace("[", "").replace("]", "") for x in spotify_df["artists"]]
spotify_df.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  explicit  valence    tempo  year  \
# 0  ['Rage Against The Machine']     False    0.503  117.906  1999
# 1  ['Rage Against The Machine']      True    0.489  103.680  1999
# 2  ['Rage Against The Machine']     False    0.370  149.749  1999
# 3  ['Rage Against The Machine']      True    0.574   96.752  1999
# 4  ['Rage Against The Machine']     False    0.539  127.059  1999
#
#   release_date  duration_sec  duration_min               new_artists
# 0   1999-11-02       210.133      3.502217  Rage Against The Machine
# 1   1999-11-02       206.200      3.436667  Rage Against The Machine
# 2   1999-11-02       298.893      4.981550  Rage Against The Machine
# 3   1999-11-02       213.640      3.560667  Rage Against The Machine
# 4   1999-11-02       205.600      3.426667  Rage Against The Machine

# %%
new_spotify = spotify_df.drop(['artists'], axis=1)
new_spotify.head()
# Out:
#                     name                      album  explicit  valence  \
# 0                Testify  The Battle Of Los Angeles     False    0.503
# 1        Guerrilla Radio  The Battle Of Los Angeles      True    0.489
# 2       Calm Like a Bomb  The Battle Of Los Angeles     False    0.370
# 3              Mic Check  The Battle Of Los Angeles      True    0.574
# 4  Sleep Now In the Fire  The Battle Of Los Angeles     False    0.539
#
#      tempo  year release_date  duration_sec  duration_min  \
# 0  117.906  1999   1999-11-02       210.133      3.502217
# 1  103.680  1999   1999-11-02       206.200      3.436667
# 2  149.749  1999   1999-11-02       298.893      4.981550
# 3   96.752  1999   1999-11-02       213.640      3.560667
# 4  127.059  1999   1999-11-02       205.600      3.426667
#
#                 new_artists
# 0  Rage Against The Machine
# 1  Rage Against The Machine
# 2  Rage Against The Machine
# 3  Rage Against The Machine
# 4  Rage Against The Machine

# %%
# spotify_df2 = spotify_df.copy()
# del spotify_df2(["artists"], ["artists_new_1"])
# spotify_df2.head()

# %%
# spotify_df_new = spotify_df2.copy()
# del spotify_df_new["artists_new"]
# spotify_df_new.head()

# %%
# # new_spotify.to_csv('Data/Spotify_output.zip')
# artist = ['Rage Against The Machine', "Elizabeth"]
# str(artist)

# %%
# artist2 = str(artist).replace("', '", "|").replace("'", "").replace("[", "").replace("]", "")
# artist2

# %%
# artist2.split("|")

# %%
# File is too large, needs to be zipped
# new_spotify.to_csv('Data/Spotify_output.csv')

# %%
# new_spotify.to_csv('Spotify_id_output.zip')

# %% [markdown]
# # **Billboard API**

# %%
# Set up billboard API- import dependencies
import billboard
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Find charts with year-end data (omit year_end to get all charts)
# billboard.charts(year_end=True)

# %%
# Top 100 songs from 2020
chart2020 = billboard.ChartData('hot-100-songs', year=2020, fetch=True)

# %%
# Get current top 100
current_100 = billboard.ChartData('hot-100')

# %%
# Filter out the data that you want from the billboard API

# Create lists to get column data
name = [] # name is the column name in Spotify, title is used in Billboard
artists = []
cur_rank = [] # current position in the charts
peak_rank = [] # peak rank in the charts
chrt_weeks = [] # number of weeks on the top 100 chart

# Append each list with the current top 100
for songs in current_100:
    song = current_100[0]
    name.append(songs.title)
    artists.append(songs.artist)
    cur_rank.append(songs.rank)
    peak_rank.append(songs.peakPos)
    chrt_weeks.append(songs.weeks)

# %%
top_songs = {
    "name": name,
    "artist": artists,
    "current_rank": cur_rank,
    "peak_rank": peak_rank,
    "weeks_on_chart": chrt_weeks
}
top_songs_df = pd.DataFrame(top_songs)

# %%
# Current week's hot 100-- weekly chart updates every Tuesday
top_songs_df.head()
# Out:
#               name                                     artist  current_rank  \
# 0             Mood               24kGoldn Featuring iann dior             1
# 1        Positions                              Ariana Grande             2
# 2  Blinding Lights                                 The Weeknd             3
# 3             Holy  Justin Bieber Featuring Chance The Rapper             4
# 4         Dynamite                                        BTS             5
#
#    peak_rank  weeks_on_chart
# 0          1              21
# 1          1              10
# 2          1              56
# 3          3              15
# 4          1              19

# %%
# new_df = top_songs_df.set_index('name')

# %%
# new_df.to_csv('Data/Billboard_output.zip')

# %%
# top_songs_df.to_csv('Data/billboard_100.csv')

# %%
# top_songs_df.to_csv('Data/Billboard__id_output.zip')

# %% [markdown]
# ### Connect to local database

# %%
# Create engine for spotify data
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base

# %%
rds_connection_string = "postgres:postgres@localhost:5432/spotify"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check table names
engine.table_names()
# Out:
# ['spotify', 'billboard']

# %%
# Spotify to sql
new_spotify.to_sql(name='spotify', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-d9883f860418> in <module>
#       1 # Spotify to sql
# ----> 2 new_spotify.to_sql(name='spotify', con=engine, if_exists='replace', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1512                 )
#    1513             else:
# -> 1514                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1515
#    1516         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# ~\anaconda3\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
# pd.read_sql_query('SELECT * FROM spotify', con=engine).head()

# %%
# Billboard to sql
top_songs_df.to_sql(name='billboard', con=engine, if_exists='replace', index=False)

# %%
# pd.read_sql_query('SELECT * FROM billboard', con=engine).head()

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()

# %%
inspector = inspect(engine)
inspector.get_table_names
# Out:
# <bound method Inspector.get_table_names of <sqlalchemy.dialects.postgresql.base.PGInspector object at 0x000001DB9A17E340>>

# %%
columns = inspector.get_columns('billboard')
for c in columns:
    print(c['name'])
# Out:
# name
# artist
# current_rank
# peak_rank
# weeks_on_chart

# %%
spotify = Base.

# %%
session = Session(engine)

# %%
session.query(spotify.name, billboard.name).limit(100).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e325cad81212> in <module>
# ----> 1 session.query(spotify.name, billboard.name).limit(100).all()
#
# NameError: name 'spotify' is not defined
